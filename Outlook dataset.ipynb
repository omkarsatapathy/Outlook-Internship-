# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\kiit\Desktop\OMKAR\Outlook dataset.csv')
df.head(10)
# Out:
#             Your Name regular What is your Favorite Magazine Brand ? quality  \
# 0      Rishabh Mishra      No                         Business Today     Yes
# 1      Rishabh Mishra      No                         Business Today     Yes
# 2         Vansheekaa      Yes                               Outlook      Yes
# 3               Ankur     Yes                               Outlook      Yes
# 4             Deepali      No                               Outlook      Yes
# 5      Adarsh Mohanty      No                               Outlook      Yes
# 6               Sonal      No                                Outlook     Yes
# 7  Binay Ku. Rautaray      No                               Top Gear     Yes
# 8               Rasmi      No                               Top Gear     Yes
# 9    Lipsa Rani Sahoo     Yes                            India today     Yes
#
#          kind color_scale       length  Price  Ratings
# 0    Economic       color  Descriptive    100        3
# ...

# %%
for i in range (50):
    if(df.iloc[i,1]) == "Yes":
        df.iloc[i,1]=1
    else:
        df.iloc[i,1]=0
df.head(5)
# Out:
#         Your Name regular What is your Favorite Magazine Brand ? quality  \
# 0  Rishabh Mishra       0                         Business Today     Yes
# 1  Rishabh Mishra       0                         Business Today     Yes
# 2     Vansheekaa        1                               Outlook      Yes
# 3           Ankur       1                               Outlook      Yes
# 4         Deepali       0                               Outlook      Yes
#
#          kind color_scale       length  Price  Ratings
# 0    Economic       color  Descriptive    100        3
# 1    Economic       color  Descriptive    100        3
# 2  Scientific       color  Descriptive    150        4
# 3    Politics       color  Descriptive     50        5
# 4  Scientific       color        short    100        3

# %%
for i in range (50):
    if(df.iloc[i,3]) == "Yes":
        df.iloc[i,3]=1
    else:
        df.iloc[i,3]=0
df.head(5)
# Out:
#         Your Name regular What is your Favorite Magazine Brand ? quality  \
# 0  Rishabh Mishra       0                         Business Today       1
# 1  Rishabh Mishra       0                         Business Today       1
# 2     Vansheekaa        1                               Outlook        1
# 3           Ankur       1                               Outlook        1
# 4         Deepali       0                               Outlook        1
#
#          kind color_scale       length  Price  Ratings
# 0    Economic       color  Descriptive    100        3
# 1    Economic       color  Descriptive    100        3
# 2  Scientific       color  Descriptive    150        4
# 3    Politics       color  Descriptive     50        5
# 4  Scientific       color        short    100        3

# %%
for i in range (50):
    if(df.iloc[i,4]) == "Crime":
        df.iloc[i,4]=1
    elif df.iloc[i,4]=="Politics":
        df.iloc[i,4] =2
    elif df.iloc[i,4]=="Scientific":
        df.iloc[i,4] =3
    elif df.iloc[i,4]=="Economic":
        df.iloc[i,4] =4
    elif df.iloc[i,4]=="OTH":
        df.iloc[i,4] =5 
df.head(5)
# Out:
#         Your Name regular What is your Favorite Magazine Brand ? quality kind  \
# 0  Rishabh Mishra       0                         Business Today       1    4
# 1  Rishabh Mishra       0                         Business Today       1    4
# 2     Vansheekaa        1                               Outlook        1    3
# 3           Ankur       1                               Outlook        1    2
# 4         Deepali       0                               Outlook        1    3
#
#   color_scale       length  Price  Ratings
# 0       color  Descriptive    100        3
# 1       color  Descriptive    100        3
# 2       color  Descriptive    150        4
# 3       color  Descriptive     50        5
# 4       color        short    100        3

# %%
for i in range (50):
    if(df.iloc[i,5]) == "color":
        df.iloc[i,5]=1
    else:
        df.iloc[i,5]=0
df.head(5)
# Out:
#         Your Name regular What is your Favorite Magazine Brand ? quality kind  \
# 0  Rishabh Mishra       0                         Business Today       1    4
# 1  Rishabh Mishra       0                         Business Today       1    4
# 2     Vansheekaa        1                               Outlook        1    3
# 3           Ankur       1                               Outlook        1    2
# 4         Deepali       0                               Outlook        1    3
#
#   color_scale       length  Price  Ratings
# 0           1  Descriptive    100        3
# 1           1  Descriptive    100        3
# 2           1  Descriptive    150        4
# 3           1  Descriptive     50        5
# 4           1        short    100        3

# %%
for i in range (50):
    if(df.iloc[i,6]) == "Descriptive":
        df.iloc[i,6]=1
    else:
        df.iloc[i,6]=0
df.head(5)
# Out:
#         Your Name regular What is your Favorite Magazine Brand ? quality kind  \
# 0  Rishabh Mishra       0                         Business Today       1    4
# 1  Rishabh Mishra       0                         Business Today       1    4
# 2     Vansheekaa        1                               Outlook        1    3
# 3           Ankur       1                               Outlook        1    2
# 4         Deepali       0                               Outlook        1    3
#
#   color_scale length  Price  Ratings
# 0           1      1    100        3
# 1           1      1    100        3
# 2           1      1    150        4
# 3           1      1     50        5
# 4           1      0    100        3

# %%
price = [20, 30, 40, 50, 60, 70,80, 90,100, 150,55,22,250, 35, 53]
for j in price:
    for i in range (50):
        if(df.iloc[i,7]) == j:
            df.iloc[i,7]=j/100
        else:
            df.iloc[i,7] = df.iloc[i,7]

# %%
fev_maz = df.pop("What is your Favorite Magazine Brand ?")
name = df.pop("Your Name")
df.head(5)
# Out:
#   regular quality kind color_scale length  Price  Ratings
# 0       0       1    4           1      1    1.0        3
# 1       0       1    4           1      1    1.0        3
# 2       1       1    3           1      1    1.5        4
# 3       1       1    2           1      1    0.5        5
# 4       0       1    3           1      0    1.0        3

# %%
import tensorflow as tf 
from tensorflow import keras
from keras.layers import Dense, Dropout

# %%
model = keras. Sequential([
    keras.layers.Dense(512, activation = 'relu', input_shape =[6]),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(256),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(128,activation = 'relu'),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(64),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(32, activation = 'relu'),
    keras.layers.Dense(1)
])
model.summary()
model.compile (loss = 'mse',
              optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_6 (Dense)              (None, 512)               3584
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 64)                8256
# ...

# %%
def scaleColumns(df, cols_to_scale):
    for col in cols_to_scale:
        df[col] = pd.DataFrame(min_max_scaler.fit_transform(pd.DataFrame(df[col])),columns=[col])
    return df

from sklearn.model_selection import train_test_split
from sklearn import preprocessing
scaler = preprocessing.MinMaxScaler()
#min_max_scaler = preprocessing.MinMaxScaler()
#scaled_df = scaleColumns(df,['regular','quality', "kind",'color_scale', 'length', 'Price', 'Ratings'])
scaled_df = scaler.fit_transform(df,['regular','quality', "kind",'color_scale', 'length', 'Price', 'Ratings'])
scaled_df = pd.DataFrame(scaled_df,columns = ['regular','quality', "kind",'color_scale', 'length', 'Price', 'Ratings'] )
#scaled_df
y = scaled_df.pop('Price')
#print(y)


X_train, X_test, y_train, y_test = train_test_split(scaled_df, y, test_size=0.1)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
#print(y_train)
# Out:
# (45, 6) (5, 6) (45,) (5,)

# %%
history = model.fit(X_train , y_train, epochs = 100,)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 4s 29ms/step - loss: 0.1087
# Epoch 2/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0656
# Epoch 3/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0477
# Epoch 4/100
# 2/2 [==============================] - 0s 14ms/step - loss: 0.0475
# Epoch 5/100
# 2/2 [==============================] - 0s 13ms/step - loss: 0.0433
# Epoch 6/100
# 2/2 [==============================] - 0s 16ms/step - loss: 0.0322
# Epoch 7/100
# 2/2 [==============================] - 0s 21ms/step - loss: 0.0489
# Epoch 8/100
# 2/2 [==============================] - 0s 25ms/step - loss: 0.0389
# Epoch 9/100
# 2/2 [==============================] - 0s 17ms/step - loss: 0.0328
# Epoch 10/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0302
# Epoch 11/100
# 2/2 [==============================] - 0s 23ms/step - loss: 0.0433
# Epoch 12/100
# 2/2 [==============================] - 0s 20ms/step - loss: 0.0372
# ...

# %%
plt.plot(history.history['loss'])
#plt.plot(history.history['val_loss'])
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %%
predict = model. predict(X_train)
predict.shape
# Out:
# (45, 1)

# %%
df_pred = pd.DataFrame(predict)
for i in range(0, 7):
    df_pred[i] = predict
#df_pred

# %%
b  = scaler.inverse_transform(df_pred)
print(pd.DataFrame(b))
# Out:
#            0         1         2         3         4         5         6
# 0   0.017562  0.017562  1.070250  0.017562  0.017562  0.240394  2.052687
# 1  -0.003264 -0.003264  0.986942 -0.003264 -0.003264  0.192492  1.990207
# 2  -0.007654 -0.007654  0.969383 -0.007654 -0.007654  0.182395  1.977037
# 3  -0.101261 -0.101261  0.594955 -0.101261 -0.101261 -0.032901  1.696216
# 4  -0.022570 -0.022570  0.909719 -0.022570 -0.022570  0.148088  1.932289
# 5  -0.082255 -0.082255  0.670980 -0.082255 -0.082255  0.010813  1.753235
# 6  -0.001987 -0.001987  0.992054 -0.001987 -0.001987  0.195431  1.994040
# 7  -0.007654 -0.007654  0.969383 -0.007654 -0.007654  0.182395  1.977037
# 8  -0.002653 -0.002653  0.989389 -0.002653 -0.002653  0.193899  1.992042
# 9  -0.003841 -0.003841  0.984636 -0.003841 -0.003841  0.191166  1.988477
# 10 -0.086373 -0.086373  0.654507 -0.086373 -0.086373  0.001341  1.740880
# 11 -0.139816 -0.139816  0.440735 -0.139816 -0.139816 -0.121577  1.580551
# ...
